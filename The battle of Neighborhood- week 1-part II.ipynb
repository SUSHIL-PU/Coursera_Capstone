# %% [markdown]
# # The Battle of Neighborhood - Week 1-part II

# %% [markdown]
# ## Data

# %% [markdown]
# In this section I am going to discuss about the data we are going to use.
# For this project I am going to analyse the New York city.

# %% [markdown]
# ## Data 1 :
# Neighborhood has a total of 5 boroughs and 306 neighborhoods. In order to segement the neighborhoods and explore them, we will essentially need a dataset that contains the 5 boroughs and the neighborhoods that exist in each borough as well as the the latitude and logitude coordinates of each neighborhood.
#
# This dataset exists for free on the web. Link to the dataset is : https://geo.nyu.edu/catalog/nyu_2451_34572
